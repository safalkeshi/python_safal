# %%
import pandas as pd

# %%
df = pd.read_json('data.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_json('data.json')
#
# File D:\python\.venv\Lib\site-packages\pandas\io\json\_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File D:\python\.venv\Lib\site-packages\pandas\io\json\_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# --> 989         obj = self._read_ujson()
#     991 return obj
#
# File D:\python\.venv\Lib\site-packages\pandas\io\json\_json.py:1035, in JsonReader._read_ujson(self)
# ...

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined
